# %%
import numpy as np

# %%
import pandas as pd

# %%
data = pd.read_excel('data_v4.xlsx')

# %%
data.head()
# Out:
#   locations_month  maxtempC  mintempC  avgtempC  sunHour  uvIndex  humidity  \
# 0   barisal2015-1      26.0      17.0      21.0     8.70      6.0      53.0
# 1   barisal2015-2      28.0      19.0      23.0     8.70      6.0      55.5
# 2   barisal2015-3      33.0      22.0      27.0    11.60      7.0      50.5
# 3   barisal2015-4      33.0      26.5      29.0    12.75      7.0      67.5
# 4   barisal2015-5      35.0      28.0      31.0    13.10      8.0      69.5
#
#    visibility  visibilityMiles  pressure  ...  cloudcover  HeatIndexC  \
# 0        10.0              6.0    1015.0  ...         1.5        24.0
# 1        10.0              6.0    1013.5  ...         9.5        26.0
# 2        10.0              6.0    1011.0  ...        13.0        30.0
# 3        10.0              6.0    1008.0  ...        31.5        34.0
# 4        10.0              6.0    1005.0  ...        37.5        38.0
#
#    DewPointC  WindChillC  FeelsLikeC  rainFall  rainDays    date locations  \
# ...

# %%
data.drop('locations_month',axis=1,inplace=True)

# %%
data.drop(['date','label'],axis=1,inplace=True)

# %%
data.head()
# Out:
#    maxtempC  mintempC  avgtempC  sunHour  uvIndex  humidity  visibility  \
# 0      26.0      17.0      21.0     8.70      6.0      53.0        10.0
# 1      28.0      19.0      23.0     8.70      6.0      55.5        10.0
# 2      33.0      22.0      27.0    11.60      7.0      50.5        10.0
# 3      33.0      26.5      29.0    12.75      7.0      67.5        10.0
# 4      35.0      28.0      31.0    13.10      8.0      69.5        10.0
#
#    visibilityMiles  pressure  pressureInches  cloudcover  HeatIndexC  \
# 0              6.0    1015.0            30.0         1.5        24.0
# 1              6.0    1013.5            30.0         9.5        26.0
# 2              6.0    1011.0            30.0        13.0        30.0
# 3              6.0    1008.0            30.0        31.5        34.0
# 4              6.0    1005.0            30.0        37.5        38.0
#
#    DewPointC  WindChillC  FeelsLikeC  rainFall  rainDays locations
# ...

# %%
loc_lst = list(data['locations'].unique())

i = 0
for haha in loc_lst:
    
    data.loc[data.locations == haha, 'locations'] = i
    i+=1

# %%
data.tail()
# Out:
#       maxtempC  mintempC  avgtempC  sunHour  uvIndex  humidity  visibility  \
# 2731      38.0      26.0      33.0     10.7      7.0      71.5         9.0
# 2732      34.0      26.0      31.0     10.8      7.0      82.0         9.0
# 2733      31.0      25.0      28.0      9.5      6.0      89.0         8.0
# 2734      33.0      25.0      30.0      9.5      6.0      87.0         7.0
# 2735      32.0      25.0      29.0      8.8      6.0      87.0         8.5
#
#       visibilityMiles  pressure  pressureInches  cloudcover  HeatIndexC  \
# 2731              5.0    1006.0            30.0        58.5        36.0
# 2732              5.0    1002.5            30.0        68.5        35.0
# 2733              4.0    1002.0            30.0        76.0        33.0
# 2734              4.0    1003.0            30.0        71.0        34.0
# 2735              5.0    1007.0            30.0        67.5        33.0
#
#       DewPointC  WindChillC  FeelsLikeC  rainFall  rainDays  locations
# ...

# %%
data.drop('pressureInches',axis=1,inplace=True)

# %%
data.corr().to_excel('pearson_correlation.xlsx','w')

# %%
from sklearn.decomposition import PCA

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
data = scaler.fit_transform(data)

# %%
pca = PCA(n_components = 10)

# %%
data = pd.DataFrame(data)

# %%
len(data[data.isnull().any(axis=1)])
# Out:
# 1254

# %%
data.dropna(inplace=True)

# %%
pca = pca.fit_transform(data)

# %%
pca.shape
# Out:
# (1482, 10)
